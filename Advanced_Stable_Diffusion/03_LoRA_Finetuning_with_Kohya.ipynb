# %% [markdown]
#  #  Step 0: Setup and Connect to Google Drive
#
#  This cell will install the necessary dependencies for the Kohya_ss GUI and connect to your Google Drive to access your images and save the output model.

# %%
from google.colab import drive
import os

print("Connecting to Google Drive...")
drive.mount('/content/drive')
print("✅ Google Drive connected.")

# Install Dependencies
# This will take a few minutes.
print("Installing dependencies for Kohya's GUI...")
# We use a specific commit for stability and quiet the output
# !git clone https://github.com/bmaltais/kohya_ss.git /content/kohya_ss
# %cd /content/kohya_ss
# !git checkout 242b528 &> /dev/null
# !./setup.sh -u

# Install diffusers for the inference part
# !pip install -q diffusers accelerate transformers torch
print("✅ Dependencies installed.")
# Out:
# Connecting to Google Drive...
# Mounted at /content/drive
# ✅ Google Drive connected.
# Installing dependencies for Kohya's GUI...
# Cloning into '/content/kohya_ss'...
# remote: Enumerating objects: 15300, done.
# remote: Counting objects: 100% (6625/6625), done.
# remote: Compressing objects: 100% (2416/2416), done.
# remote: Total 15300 (delta 4288), reused 4209 (delta 4209), pack-reused 8675 (from 1)
# Receiving objects: 100% (15300/15300), 23.59 MiB | 31.29 MiB/s, done.
# Resolving deltas: 100% (10796/10796), done.
# /content/kohya_ss
# Skipping git operations.
# Ubuntu detected.
# Python TK found...
# Switching to virtual Python environment.
# [06/21/25 15:30:25] INFO     Python version is 3.11.13 (main, ]8;id=167804;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=595679;file:///content/kohya_ss/setup/setup_common.py#28\28]8;;\
#                              Jun  4 2025, 08:57:29) [GCC
#                              11.4.0]
# [06/21/25 15:30:26] INFO     Submodule initialized and        ]8;id=45660;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=13887;file:///content/kohya_ss/setup/setup_common.py#53\53]8;;\
#                              updated.
#                     INFO     Installing python dependencies.   ]8;id=497469;file:///content/kohya_ss/setup/setup_linux.py\setup_linux.py]8;;\:]8;id=246512;file:///content/kohya_ss/setup/setup_linux.py#14\14]8;;\
#                              This could take a few minutes as
#                              it downloads files.
#                     INFO     If this operation ever runs too   ]8;id=35054;file:///content/kohya_ss/setup/setup_linux.py\setup_linux.py]8;;\:]8;id=677892;file:///content/kohya_ss/setup/setup_linux.py#15\15]8;;\
#                              long, you can rerun this script
#                              in verbose mode to check.
#                     INFO     Kohya_ss GUI version: v25.2.0   ]8;id=698568;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=106052;file:///content/kohya_ss/setup/setup_common.py#377\377]8;;\
#
#                     INFO     Installing/Validating           ]8;id=766720;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=684046;file:///content/kohya_ss/setup/setup_common.py#161\161]8;;\
#                              requirements from
#                              requirements_linux.txt...
# [06/21/25 15:30:28] INFO     Looking in indexes:             ]8;id=535440;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=299284;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              https://pypi.org/simple,
#                              https://download.pytorch.org/wh
#                              l/cu128
#                     INFO     Obtaining                       ]8;id=527111;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=879979;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              file:///content/kohya_ss/sd-scr
#                              ipts (from -r requirements.txt
#                              (line 38))
#                     INFO     Preparing metadata (setup.py):  ]8;id=996435;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=201762;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              started
#                     INFO     Preparing metadata (setup.py):  ]8;id=687551;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=32613;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              finished with status 'done'
# [06/21/25 15:30:29] INFO     Collecting torch==2.7.0+cu128   ]8;id=662649;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=329361;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (from -r requirements_linux.txt
#                              (line 4))
#                     INFO     Downloading                     ]8;id=410228;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=305744;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              https://download.pytorch.org/wh
#                              l/cu128/torch-2.7.0%2Bcu128-cp3
#                              11-cp311-manylinux_2_28_x86_64.
#                              whl.metadata (29 kB)
#                     INFO     Collecting                      ]8;id=780851;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=559831;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              torchvision==0.22.0+cu128 (from
#                              -r requirements_linux.txt (line
#                              5))
#                     INFO     Downloading                     ]8;id=597716;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=232465;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              https://download.pytorch.org/wh
#                              l/cu128/torchvision-0.22.0%2Bcu
#                              128-cp311-cp311-manylinux_2_28_
#                              x86_64.whl.metadata (6.1 kB)
# [06/21/25 15:30:30] INFO     Collecting xformers>=0.0.30     ]8;id=590922;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=246985;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (from -r requirements_linux.txt
#                              (line 6))
#                     INFO     Downloading                     ]8;id=619121;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=577321;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              https://download.pytorch.org/wh
#                              l/cu128/xformers-0.0.30-cp311-c
#                              p311-manylinux_2_28_x86_64.whl.
#                              metadata (1.0 kB)
#                     INFO     Collecting bitsandbytes>=0.45.0 ]8;id=850445;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=533373;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (from -r requirements_linux.txt
#                              (line 8))
#                     INFO     Downloading                     ]8;id=704197;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=623253;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              bitsandbytes-0.46.0-py3-none-ma
#                              nylinux_2_24_x86_64.whl.metadat
#                              a (10 kB)
#                     INFO     Collecting tensorboard==2.15.2  ]8;id=949304;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=844713;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (from -r requirements_linux.txt
#                              (line 9))
#                     INFO     Downloading                     ]8;id=327554;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=36663;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              tensorboard-2.15.2-py3-none-any
#                              .whl.metadata (1.7 kB)
# [06/21/25 15:30:31] INFO     Collecting                      ]8;id=834099;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=533480;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              tensorflow==2.15.0.post1 (from
#                              -r requirements_linux.txt (line
#                              10))
#                     INFO     Downloading                     ]8;id=16885;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=916269;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              tensorflow-2.15.0.post1-cp311-c
#                              p311-manylinux_2_17_x86_64.many
#                              linux2014_x86_64.whl.metadata
#                              (4.2 kB)
#                     INFO     Collecting                      ]8;id=594262;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=105408;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              onnxruntime-gpu==1.19.2 (from
#                              -r requirements_linux.txt (line
#                              11))
#                     INFO     Downloading                     ]8;id=986498;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=891893;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              onnxruntime_gpu-1.19.2-cp311-cp
#                              311-manylinux_2_27_x86_64.manyl
#                              inux_2_28_x86_64.whl.metadata
#                              (4.5 kB)
#                     INFO     Collecting aiofiles==23.2.1     ]8;id=896103;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=308129;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (from -r requirements.txt (line
#                              2))
#                     INFO     Downloading                     ]8;id=640259;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=962566;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              aiofiles-23.2.1-py3-none-any.wh
#                              l.metadata (9.7 kB)
# [06/21/25 15:30:32] INFO     Collecting altair==4.2.2 (from  ]8;id=778416;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=71079;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              -r requirements.txt (line 3))
#                     INFO     Downloading                     ]8;id=797288;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=538849;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              altair-4.2.2-py3-none-any.whl.m
#                              etadata (13 kB)
#                     INFO     Collecting dadaptation==3.2     ]8;id=845567;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=473648;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (from -r requirements.txt (line
#                              4))
#                     INFO     Downloading                     ]8;id=490929;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=549418;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              dadaptation-3.2.tar.gz (13 kB)
#                     INFO     Installing build dependencies:  ]8;id=894812;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=633738;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              started
# [06/21/25 15:30:38] INFO     Installing build dependencies:  ]8;id=118111;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=386942;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              finished with status 'done'
#                     INFO     Getting requirements to build   ]8;id=453061;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=498945;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              wheel: started
#                     INFO     Getting requirements to build   ]8;id=283967;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=608882;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              wheel: finished with status
#                              'done'
#                     INFO     Preparing metadata              ]8;id=476020;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=392566;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (pyproject.toml): started
#                     INFO     Preparing metadata              ]8;id=93630;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=278444;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (pyproject.toml): finished with
#                              status 'done'
#                     INFO     Collecting diffusers==0.32.2    ]8;id=874976;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=798543;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (from
#                              diffusers[torch]==0.32.2->-r
#                              requirements.txt (line 5))
#                     INFO     Downloading                     ]8;id=131300;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=780687;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              diffusers-0.32.2-py3-none-any.w
#                              hl.metadata (18 kB)
# [06/21/25 15:30:39] INFO     Collecting easygui==0.98.3      ]8;id=737782;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=176856;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (from -r requirements.txt (line
#                              6))
#                     INFO     Downloading                     ]8;id=187086;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=444168;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              easygui-0.98.3-py2.py3-none-any
#                              .whl.metadata (8.4 kB)
#                     INFO     Collecting einops==0.7.0 (from  ]8;id=656387;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=814354;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              -r requirements.txt (line 7))
#                     INFO     Downloading                     ]8;id=376820;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=411369;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              einops-0.7.0-py3-none-any.whl.m
#                              etadata (13 kB)
#                     INFO     Collecting fairscale==0.4.13    ]8;id=354351;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=148736;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (from -r requirements.txt (line
#                              8))
#                     INFO     Downloading                     ]8;id=787698;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=162359;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              fairscale-0.4.13.tar.gz (266
#                              kB)
#                     INFO     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ ]8;id=778661;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=740791;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              ━━━━━━━━ 266.3/266.3 kB 9.8
#                              MB/s eta 0:00:00
#                     INFO     Installing build dependencies:  ]8;id=306656;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=809664;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              started
# [06/21/25 15:30:52] INFO     Installing build dependencies:  ]8;id=782313;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=93377;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              finished with status 'done'
#                     INFO     Getting requirements to build   ]8;id=835990;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=203775;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              wheel: started
#                     INFO     Getting requirements to build   ]8;id=322788;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=705467;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              wheel: finished with status
#                              'done'
#                     INFO     Installing backend              ]8;id=439738;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=114596;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              dependencies: started
# [06/21/25 15:30:54] INFO     Installing backend              ]8;id=565874;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=741831;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              dependencies: finished with
#                              status 'done'
#                     INFO     Preparing metadata              ]8;id=606044;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=27981;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (pyproject.toml): started
# [06/21/25 15:30:55] INFO     Preparing metadata              ]8;id=173424;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=679176;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (pyproject.toml): finished with
#                              status 'done'
#                     INFO     Collecting ftfy==6.1.1 (from -r ]8;id=393843;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=575708;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              requirements.txt (line 9))
#                     INFO     Downloading                     ]8;id=418402;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=98012;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              ftfy-6.1.1-py3-none-any.whl.met
#                              adata (6.1 kB)
#                     INFO     Collecting                      ]8;id=112056;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=709477;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              huggingface-hub==0.29.3 (from
#                              -r requirements.txt (line 11))
#                     INFO     Downloading                     ]8;id=496175;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=534862;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              huggingface_hub-0.29.3-py3-none
#                              -any.whl.metadata (13 kB)
# [06/21/25 15:30:56] INFO     Collecting                      ]8;id=140373;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=951965;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              invisible-watermark==0.2.0
#                              (from -r requirements.txt (line
#                              13))
#                     INFO     Downloading                     ]8;id=711027;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=645843;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              invisible_watermark-0.2.0-py3-n
#                              one-any.whl.metadata (8.2 kB)
#                     INFO     Collecting lion-pytorch==0.0.6  ]8;id=199475;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=220513;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (from -r requirements.txt (line
#                              14))
#                     INFO     Downloading                     ]8;id=110537;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=794827;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              lion_pytorch-0.0.6-py3-none-any
#                              .whl.metadata (620 bytes)
#                     INFO     Collecting                      ]8;id=195863;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=93569;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              lycoris_lora==3.2.0.post2 (from
#                              -r requirements.txt (line 15))
#                     INFO     Downloading                     ]8;id=599488;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=114855;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              lycoris_lora-3.2.0.post2.tar.gz
#                              (53 kB)
#                     INFO     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ ]8;id=973245;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=552259;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              ━━━━━━━━━ 53.7/53.7 kB 5.0 MB/s
#                              eta 0:00:00
#                     INFO     Preparing metadata (setup.py):  ]8;id=674815;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=667978;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              started
# [06/21/25 15:30:57] INFO     Preparing metadata (setup.py):  ]8;id=856358;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=879635;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              finished with status 'done'
#                     INFO     Collecting onnx==1.16.1 (from   ]8;id=301510;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=162953;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              -r requirements.txt (line 17))
#                     INFO     Downloading                     ]8;id=125189;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=273980;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              onnx-1.16.1-cp311-cp311-manylin
#                              ux_2_17_x86_64.manylinux2014_x8
#                              6_64.whl.metadata (16 kB)
#                     INFO     Collecting prodigyopt==1.1.2    ]8;id=689203;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=514521;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (from -r requirements.txt (line
#                              18))
#                     INFO     Downloading                     ]8;id=971598;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=772717;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              prodigyopt-1.1.2-py3-none-any.w
#                              hl.metadata (4.8 kB)
# [06/21/25 15:30:58] INFO     Collecting protobuf==3.20.3     ]8;id=639871;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=200878;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (from -r requirements.txt (line
#                              19))
#                     INFO     Downloading                     ]8;id=975533;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=544117;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              protobuf-3.20.3-py2.py3-none-an
#                              y.whl.metadata (720 bytes)
#                     INFO     Collecting                      ]8;id=315107;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=589285;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              open-clip-torch==2.20.0 (from
#                              -r requirements.txt (line 20))
#                     INFO     Downloading                     ]8;id=435512;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=189746;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              open_clip_torch-2.20.0-py3-none
#                              -any.whl.metadata (46 kB)
#                     INFO     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ ]8;id=711695;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=577213;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              ━━━━━━━━━ 46.8/46.8 kB 4.6 MB/s
#                              eta 0:00:00
# [06/21/25 15:30:59] INFO     Collecting                      ]8;id=216873;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=664046;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              opencv-python==4.10.0.84 (from
#                              -r requirements.txt (line 21))
#                     INFO     Downloading                     ]8;id=480041;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=287279;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              opencv_python-4.10.0.84-cp37-ab
#                              i3-manylinux_2_17_x86_64.manyli
#                              nux2014_x86_64.whl.metadata (20
#                              kB)
#                     INFO     Collecting                      ]8;id=723869;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=623185;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              prodigy-plus-schedule-free==1.8
#                              .0 (from -r requirements.txt
#                              (line 22))
#                     INFO     Downloading                     ]8;id=849041;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=199797;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              prodigy_plus_schedule_free-1.8.
#                              0-py3-none-any.whl.metadata
#                              (8.1 kB)
# [06/21/25 15:31:00] INFO     Collecting                      ]8;id=930155;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=271665;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              pytorch-lightning==1.9.0 (from
#                              -r requirements.txt (line 23))
#                     INFO     Downloading                     ]8;id=736424;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=955084;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              pytorch_lightning-1.9.0-py3-non
#                              e-any.whl.metadata (23 kB)
#                     INFO     Collecting                      ]8;id=339319;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=567699;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              pytorch-optimizer==3.5.0 (from
#                              -r requirements.txt (line 24))
#                     INFO     Downloading                     ]8;id=967676;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=875162;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              pytorch_optimizer-3.5.0-py3-non
#                              e-any.whl.metadata (71 kB)
#                     INFO     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ ]8;id=422120;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=996687;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              ━━━━━━━━━ 71.9/71.9 kB 6.9 MB/s
#                              eta 0:00:00
# [06/21/25 15:31:01] INFO     Collecting safetensors==0.4.4   ]8;id=37160;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=89986;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (from -r requirements.txt (line
#                              26))
#                     INFO     Downloading                     ]8;id=356994;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=344040;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              safetensors-0.4.4-cp311-cp311-m
#                              anylinux_2_17_x86_64.manylinux2
#                              014_x86_64.whl.metadata (3.8
#                              kB)
#                     INFO     Collecting schedulefree==1.4    ]8;id=153192;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=817118;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (from -r requirements.txt (line
#                              27))
#                     INFO     Downloading                     ]8;id=858076;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=511130;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              schedulefree-1.4.tar.gz (22 kB)
#                     INFO     Installing build dependencies:  ]8;id=809032;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=10840;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              started
# [06/21/25 15:31:06] INFO     Installing build dependencies:  ]8;id=305798;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=13520;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              finished with status 'done'
#                     INFO     Getting requirements to build   ]8;id=414470;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=796270;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              wheel: started
#                     INFO     Getting requirements to build   ]8;id=278691;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=644093;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              wheel: finished with status
#                              'done'
#                     INFO     Preparing metadata              ]8;id=636294;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=239421;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (pyproject.toml): started
#                     INFO     Preparing metadata              ]8;id=277184;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=217924;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (pyproject.toml): finished with
#                              status 'done'
# [06/21/25 15:31:07] INFO     Collecting scipy==1.11.4 (from  ]8;id=602867;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=14269;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              -r requirements.txt (line 28))
#                     INFO     Downloading                     ]8;id=889323;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=612942;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              scipy-1.11.4-cp311-cp311-manyli
#                              nux_2_17_x86_64.manylinux2014_x
#                              86_64.whl.metadata (60 kB)
#                     INFO     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ ]8;id=639870;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=580016;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              ━━━━━━━━━ 60.4/60.4 kB 5.0 MB/s
#                              eta 0:00:00
#                     INFO     Collecting timm==0.6.7 (from -r ]8;id=294636;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=839578;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              requirements.txt (line 31))
#                     INFO     Downloading                     ]8;id=529140;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=125634;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              timm-0.6.7-py3-none-any.whl.met
#                              adata (33 kB)
# [06/21/25 15:31:08] INFO     Collecting tk==0.1.0 (from -r   ]8;id=650884;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=839120;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              requirements.txt (line 32))
#                     INFO     Downloading                     ]8;id=658720;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=704376;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              tk-0.1.0-py3-none-any.whl.metad
#                              ata (693 bytes)
#                     INFO     Collecting transformers==4.44.2 ]8;id=464385;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=941616;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (from -r requirements.txt (line
#                              34))
#                     INFO     Downloading                     ]8;id=454487;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=509165;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              transformers-4.44.2-py3-none-an
#                              y.whl.metadata (43 kB)
#                     INFO     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ ]8;id=485611;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=657422;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              ━━━━━━━━━ 43.7/43.7 kB 4.1 MB/s
#                              eta 0:00:00
#                     INFO     Collecting voluptuous==0.13.1   ]8;id=522347;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=528441;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              (from -r requirements.txt (line
#                              35))
#                     INFO     Downloading                     ]8;id=376269;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=150497;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              voluptuous-0.13.1-py3-none-any.
#                              whl.metadata (20 kB)
# [06/21/25 15:31:09] INFO     Collecting wandb==0.18.0 (from  ]8;id=296075;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=619842;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              -r requirements.txt (line 36))
#                     INFO     Downloading                     ]8;id=507348;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=138468;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              wandb-0.18.0-py3-none-manylinux
#                              _2_17_x86_64.manylinux2014_x86_
#                              64.whl.metadata (9.6 kB)
#                     INFO     Collecting sympy>=1.13.3 (from  ]8;id=107661;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=11776;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              torch==2.7.0+cu128->-r
#                              requirements_linux.txt (line
#                              4))
#                     INFO     Downloading                     ]8;id=15355;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=438593;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              sympy-1.14.0-py3-none-any.whl.m
#                              etadata (12 kB)
#                     INFO     Collecting                      ]8;id=109346;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=592178;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              nvidia-cuda-nvrtc-cu12==12.8.61
#                              (from torch==2.7.0+cu128->-r
#                              requirements_linux.txt (line
#                              4))
#                     INFO     Downloading                     ]8;id=748251;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=275827;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              https://download.pytorch.org/wh
#                              l/cu128/nvidia_cuda_nvrtc_cu12-
#                              12.8.61-py3-none-manylinux2010_
#                              x86_64.manylinux_2_12_x86_64.wh
#                              l.metadata (1.7 kB)
# [06/21/25 15:31:10] INFO     Collecting                      ]8;id=562142;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=862700;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              nvidia-cuda-runtime-cu12==12.8.
#                              57 (from torch==2.7.0+cu128->-r
#                              requirements_linux.txt (line
#                              4))
#                     INFO     Downloading                     ]8;id=908875;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=845213;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              https://download.pytorch.org/wh
#                              l/cu128/nvidia_cuda_runtime_cu1
#                              2-12.8.57-py3-none-manylinux201
#                              4_x86_64.manylinux_2_17_x86_64.
#                              whl.metadata (1.7 kB)
#                     INFO     Collecting                      ]8;id=910587;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=834153;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              nvidia-cuda-cupti-cu12==12.8.57
#                              (from torch==2.7.0+cu128->-r
#                              requirements_linux.txt (line
#                              4))
#                     INFO     Downloading                     ]8;id=770359;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=832948;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              https://download.pytorch.org/wh
#                              l/cu128/nvidia_cuda_cupti_cu12-
#                              12.8.57-py3-none-manylinux2014_
#                              x86_64.manylinux_2_17_x86_64.wh
#                              l.metadata (1.7 kB)
#                     INFO     Collecting                      ]8;id=148164;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=730924;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              nvidia-cudnn-cu12==9.7.1.26
#                              (from torch==2.7.0+cu128->-r
#                              requirements_linux.txt (line
#                              4))
#                     INFO     Downloading                     ]8;id=939645;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=455492;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              https://download.pytorch.org/wh
#                              l/cu128/nvidia_cudnn_cu12-9.7.1
#                              .26-py3-none-manylinux_2_27_x86
#                              _64.whl.metadata (1.8 kB)
#                     INFO     Collecting                      ]8;id=875341;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=598169;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              nvidia-cublas-cu12==12.8.3.14
#                              (from torch==2.7.0+cu128->-r
#                              requirements_linux.txt (line
#                              4))
#                     INFO     Downloading                     ]8;id=20592;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=954237;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              https://download.pytorch.org/wh
#                              l/cu128/nvidia_cublas_cu12-12.8
#                              .3.14-py3-none-manylinux_2_27_x
#                              86_64.whl.metadata (1.7 kB)
# [06/21/25 15:31:11] INFO     Collecting                      ]8;id=694244;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=905072;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              nvidia-cufft-cu12==11.3.3.41
#                              (from torch==2.7.0+cu128->-r
# ...
#                              tokenizers 0.21.1
#                     INFO     Uninstalling tokenizers-0.21.1: ]8;id=172079;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=750569;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                     INFO     Successfully uninstalled        ]8;id=458697;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=904614;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              tokenizers-0.21.1
# [06/21/25 15:36:10] INFO     Attempting uninstall:           ]8;id=419886;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=108166;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              nvidia-cusolver-cu12
#                     INFO     Found existing installation:    ]8;id=760610;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=681519;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              nvidia-cusolver-cu12 11.6.3.83
#                     INFO     Uninstalling                    ]8;id=777032;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=822370;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              nvidia-cusolver-cu12-11.6.3.83:
# [06/21/25 15:36:11] INFO     Successfully uninstalled        ]8;id=861334;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=814486;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              nvidia-cusolver-cu12-11.6.3.83
# [06/21/25 15:36:18] INFO     Attempting uninstall: diffusers ]8;id=4760;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=79256;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                     INFO     Found existing installation:    ]8;id=365915;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=147837;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              diffusers 0.33.1
# [06/21/25 15:36:19] INFO     Uninstalling diffusers-0.33.1:  ]8;id=413268;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=386180;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                     INFO     Successfully uninstalled        ]8;id=959110;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=182330;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              diffusers-0.33.1
# [06/21/25 15:36:21] INFO     Attempting uninstall:           ]8;id=475297;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=435261;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              transformers
#                     INFO     Found existing installation:    ]8;id=340335;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=176908;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              transformers 4.52.4
#                     INFO     Uninstalling                    ]8;id=867395;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=919248;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              transformers-4.52.4:
# [06/21/25 15:36:23] INFO     Successfully uninstalled        ]8;id=209141;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=388140;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              transformers-4.52.4
# [06/21/25 15:36:28] INFO     Attempting uninstall: torch     ]8;id=762030;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=750532;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
# [06/21/25 15:36:29] INFO     Found existing installation:    ]8;id=730869;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=679702;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              torch 2.6.0+cu124
#                     INFO     Uninstalling torch-2.6.0+cu124: ]8;id=816293;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=33463;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
# [06/21/25 15:36:51] INFO     Successfully uninstalled        ]8;id=180894;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=456867;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              torch-2.6.0+cu124
# [06/21/25 15:37:23] INFO     Attempting uninstall:           ]8;id=939235;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=792352;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              tensorboard
#                     INFO     Found existing installation:    ]8;id=155385;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=890206;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              tensorboard 2.18.0
#                     INFO     Uninstalling                    ]8;id=378435;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=415381;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              tensorboard-2.18.0:
# [06/21/25 15:37:24] INFO     Successfully uninstalled        ]8;id=450707;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=691762;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              tensorboard-2.18.0
#                     INFO     Attempting uninstall: altair    ]8;id=201377;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=344743;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                     INFO     Found existing installation:    ]8;id=202655;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=700566;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              altair 5.5.0
#                     INFO     Uninstalling altair-5.5.0:      ]8;id=813178;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=923182;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                     INFO     Successfully uninstalled        ]8;id=962594;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=952969;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              altair-5.5.0
# [06/21/25 15:37:26] INFO     Attempting uninstall:           ]8;id=41986;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=407748;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              torchvision
#                     INFO     Found existing installation:    ]8;id=628313;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=166707;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              torchvision 0.21.0+cu124
#                     INFO     Uninstalling                    ]8;id=844402;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=341563;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              torchvision-0.21.0+cu124:
# [06/21/25 15:37:27] INFO     Successfully uninstalled        ]8;id=340373;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=478671;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              torchvision-0.21.0+cu124
# [06/21/25 15:37:28] INFO     Attempting uninstall:           ]8;id=971493;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=926315;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              tensorflow
#                     INFO     Found existing installation:    ]8;id=871751;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=59699;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              tensorflow 2.18.0
# [06/21/25 15:37:29] INFO     Uninstalling tensorflow-2.18.0: ]8;id=805920;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=603864;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
# [06/21/25 15:37:54] INFO     Successfully uninstalled        ]8;id=572021;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=891892;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              tensorflow-2.18.0
# [06/21/25 15:38:17] INFO     Attempting uninstall: timm      ]8;id=243340;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=823520;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                     INFO     Found existing installation:    ]8;id=802197;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=465301;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              timm 1.0.15
#                     INFO     Uninstalling timm-1.0.15:       ]8;id=775670;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=650887;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
# [06/21/25 15:38:18] INFO     Successfully uninstalled        ]8;id=386866;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=361263;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              timm-1.0.15
# [06/21/25 15:38:20] INFO     Successfully installed          ]8;id=808879;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=826627;file:///content/kohya_ss/setup/setup_common.py#189\189]8;;\
#                              aiofiles-23.2.1 altair-4.2.2
#                              bitsandbytes-0.46.0
#                              coloredlogs-15.0.1
#                              dadaptation-3.2
#                              diffusers-0.32.2
#                              docker-pycreds-0.4.0
#                              easygui-0.98.3 einops-0.7.0
#                              fairscale-0.4.13 ftfy-6.1.1
#                              huggingface-hub-0.29.3
#                              humanfriendly-10.0
#                              invisible-watermark-0.2.0
#                              keras-2.15.0 library-0.0.0
#                              lightning-utilities-0.14.3
#                              lion-pytorch-0.0.6
#                              lycoris_lora-3.2.0.post2
#                              ml-dtypes-0.2.0 numpy-1.26.4
#                              nvidia-cublas-cu12-12.8.3.14
#                              nvidia-cuda-cupti-cu12-12.8.57
#                              nvidia-cuda-nvrtc-cu12-12.8.61
#                              nvidia-cuda-runtime-cu12-12.8.5
#                              7 nvidia-cudnn-cu12-9.7.1.26
#                              nvidia-cufft-cu12-11.3.3.41
#                              nvidia-cufile-cu12-1.13.0.11
#                              nvidia-curand-cu12-10.3.9.55
#                              nvidia-cusolver-cu12-11.7.2.55
#                              nvidia-cusparse-cu12-12.5.7.53
#                              nvidia-cusparselt-cu12-0.6.3
#                              nvidia-nccl-cu12-2.26.2
#                              nvidia-nvjitlink-cu12-12.8.61
#                              nvidia-nvtx-cu12-12.8.55
#                              onnx-1.16.1
#                              onnxruntime-gpu-1.19.2
#                              open-clip-torch-2.20.0
#                              opencv-python-4.10.0.84
#                              prodigy-plus-schedule-free-1.8.
#                              0 prodigyopt-1.1.2
#                              protobuf-3.20.3
#                              pytorch-lightning-1.9.0
#                              pytorch-optimizer-3.5.0
#                              safetensors-0.4.4
#                              schedulefree-1.4 scipy-1.11.4
#                              sympy-1.14.0 tensorboard-2.15.2
#                              tensorflow-2.15.0.post1
#                              tensorflow-estimator-2.15.0
#                              timm-0.6.7 tk-0.1.0
#                              tokenizers-0.19.1
#                              torch-2.7.0+cu128
#                              torchmetrics-1.7.3
#                              torchvision-0.22.0+cu128
#                              transformers-4.44.2
#                              triton-3.3.0 voluptuous-0.13.1
#                              wandb-0.18.0 wrapt-1.14.1
#                              xformers-0.0.30
# [06/21/25 15:38:21] INFO     Configuring accelerate...       ]8;id=849857;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=946974;file:///content/kohya_ss/setup/setup_common.py#207\207]8;;\
#                     WARNING  Could not automatically         ]8;id=851536;file:///content/kohya_ss/setup/setup_common.py\setup_common.py]8;;\:]8;id=903265;file:///content/kohya_ss/setup/setup_common.py#280\280]8;;\
#                              configure accelerate. Please
#                              manually configure accelerate
#                              with the option in the menu or
#                              with: accelerate config.
# Setup finished! Run ./gui.sh to start.
# Please note if you'd like to expose your public server you need to run ./gui.sh --share
# ✅ Dependencies installed.

# %% [markdown]
# # Step 1: Launch the Kohya_ss GUI
#
# Run this cell to start the web interface.
#
# A public URL (like `...gradio.live`) will appear in the output below. Click it to open the GUI in a new tab.

# %%
# %cd /content/kohya_ss

# !python /content/kohya_ss/kohya_gui.py --listen 127.0.0.1 --server_port 7860 --inbrowser --share
# Out:
# /content/kohya_ss
# 2025-06-21 15:41:10.285466: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-06-21 15:41:10.285523: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-21 15:41:10.288030: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-21 15:41:10.297690: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-21 15:41:11.705932: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# DEBUG:2025-06-21 15:41:13,159:jax._src.path:31: etils.epath found. Using etils.epath for file I/O.
# 15:41:25-475181 INFO     Kohya_ss GUI version: v25.2.0
#
# 15:41:25-621878 INFO     Submodule initialized and updated.
# 15:41:25-622971 INFO     nVidia toolkit detected
# 15:41:27-165071 INFO     Torch 2.7.0+cu128
# 15:41:27-248203 INFO     Torch backend: nVidia CUDA 12.8 cuDNN 90701
# 15:41:27-270344 INFO     Torch detected GPU: Tesla T4 VRAM 15095MB Arch 7.5
#                          Cores 40
# 15:41:27-272239 INFO     Python version is 3.11.13 (main, Jun  4 2025, 08:57:29)
#                          [GCC 11.4.0]
# 15:41:27-273956 INFO     Installing/Validating requirements from
#                          requirements_pytorch_windows.txt...
# 15:41:28-756307 INFO     Looking in indexes: https://pypi.org/simple,
#                          https://download.pytorch.org/whl/cu128
# 15:41:28-759823 INFO     Obtaining file:///content/kohya_ss/sd-scripts (from -r
#                          requirements.txt (line 38))
# 15:41:28-763792 INFO     Preparing metadata (setup.py): started
# 15:41:29-307342 INFO     Preparing metadata (setup.py): finished with status
#                          'done'
# 15:41:30-372738 INFO     Collecting tensorflow>=2.16.1 (from -r
#                          requirements_windows.txt (line 3))
# 15:41:30-409377 INFO     Downloading
#                          tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.man
#                          ylinux2014_x86_64.whl.metadata (4.1 kB)
# 15:41:31-128636 INFO     Collecting tensorboard (from -r
#                          requirements_windows.txt (line 2))
# 15:41:31-142236 INFO     Downloading
#                          tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# 15:41:31-442621 INFO     Collecting keras>=3.5.0 (from tensorflow>=2.16.1->-r
#                          requirements_windows.txt (line 3))
# 15:41:31-452757 INFO     Downloading keras-3.10.0-py3-none-any.whl.metadata (6.0
#                          kB)
# 15:41:31-762915 INFO     Collecting ml-dtypes<1.0.0,>=0.5.1 (from
#                          tensorflow>=2.16.1->-r requirements_windows.txt (line
#                          3))
# 15:41:31-774207 INFO     Downloading
#                          ml_dtypes-0.5.1-cp311-cp311-manylinux_2_17_x86_64.manyl
#                          inux2014_x86_64.whl.metadata (21 kB)
# 15:41:32-519776 INFO     Downloading
#                          tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.man
#                          ylinux2014_x86_64.whl (644.9 MB)
# 15:41:42-471575 INFO     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 MB
#                          2.8 MB/s eta 0:00:00
# 15:41:42-480743 INFO     Downloading tensorboard-2.19.0-py3-none-any.whl (5.5
#                          MB)
# 15:41:42-572046 INFO     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB
#                          65.2 MB/s eta 0:00:00
# 15:41:42-591052 INFO     Downloading keras-3.10.0-py3-none-any.whl (1.4 MB)
# 15:41:42-630284 INFO     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB
#                          54.0 MB/s eta 0:00:00
# 15:41:42-643468 INFO     Downloading
#                          ml_dtypes-0.5.1-cp311-cp311-manylinux_2_17_x86_64.manyl
#                          inux2014_x86_64.whl (4.7 MB)
# 15:41:42-735890 INFO     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB
#                          55.3 MB/s eta 0:00:00
# 15:41:46-266634 INFO     Installing collected packages: library, ml-dtypes,
#                          tensorboard, keras, tensorflow
# 15:41:46-268475 INFO     Attempting uninstall: library
# 15:41:46-478235 INFO     Found existing installation: library 0.0.0
# 15:41:46-480545 INFO     Uninstalling library-0.0.0:
# 15:41:47-428891 INFO     Successfully uninstalled library-0.0.0
# 15:41:47-430793 INFO     Running setup.py develop for library
# 15:41:48-397697 INFO     Attempting uninstall: ml-dtypes
# 15:41:48-408546 INFO     Found existing installation: ml-dtypes 0.2.0
# 15:41:48-419752 INFO     Uninstalling ml-dtypes-0.2.0:
# 15:41:48-423250 INFO     Successfully uninstalled ml-dtypes-0.2.0
# 15:41:48-546780 INFO     Attempting uninstall: tensorboard
# 15:41:48-566652 INFO     Found existing installation: tensorboard 2.15.2
# 15:41:48-593467 INFO     Uninstalling tensorboard-2.15.2:
# 15:41:48-599948 INFO     Successfully uninstalled tensorboard-2.15.2
# 15:41:48-975429 INFO     Attempting uninstall: keras
# 15:41:48-991180 INFO     Found existing installation: keras 2.15.0
# 15:41:49-057353 INFO     Uninstalling keras-2.15.0:
# 15:41:49-072136 INFO     Successfully uninstalled keras-2.15.0
# 15:41:50-038624 INFO     Attempting uninstall: tensorflow
# 15:41:50-070292 INFO     Found existing installation: tensorflow 2.15.0.post1
# 15:41:50-530271 INFO     Uninstalling tensorflow-2.15.0.post1:
# 15:41:50-643968 INFO     Successfully uninstalled tensorflow-2.15.0.post1
# 15:42:16-219358 INFO     Successfully installed keras-3.10.0 library-0.0.0
#                          ml-dtypes-0.5.1 tensorboard-2.19.0 tensorflow-2.19.0
# 15:42:19-788424 INFO     headless: False
# 15:42:19-793983 INFO     Using shell=True when running external commands...
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://a61699baaac1b916b7.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 15:54:06-233539 INFO     Start training LoRA Standard ...
# 15:54:06-234846 INFO     Validating lr scheduler arguments...
# 15:54:06-235982 INFO     Validating optimizer arguments...
# 15:54:06-237625 INFO     Validating
#                          /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/
#                          Assignment08_SD_GEN/lora_output existence and
#                          writability... SUCCESS
# 15:54:06-239183 INFO     Validating
#                          /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/
#                          Assignment08_SD_GEN/Qajar_LoRA_Model existence and
#                          writability... SUCCESS
# 15:54:06-240413 INFO     Validating runwayml/stable-diffusion-v1-5 existence...
#                          SKIPPING: huggingface.co model
# 15:54:06-241662 INFO     Validating
#                          /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/
#                          Assignment08_SD_GEN/qajar_images existence... SUCCESS
# 15:54:06-249973 INFO     Folder 001_qajar: 1 repeats found
# 15:54:06-251671 INFO     Folder 001_qajar: 19 images found
# 15:54:06-252519 INFO     Folder 001_qajar: 19 * 1 = 19 steps
# 15:54:06-253382 INFO     Regularization factor: 1
# 15:54:06-254145 INFO     Train batch size: 1
# 15:54:06-254873 INFO     Gradient accumulation steps: 1
# 15:54:06-255659 INFO     Epoch: 10
# 15:54:06-256409 INFO     Max train steps: 1600
# 15:54:06-257145 INFO     stop_text_encoder_training = 0
# 15:54:06-257890 INFO     lr_warmup_steps = 0.1
# 15:54:06-258955 INFO     Effective Learning Rate Configuration (based on GUI
#                          settings):
# 15:54:06-259857 INFO       - Main LR (for optimizer & fallback): 1.00e-04
# 15:54:06-260713 INFO       - Text Encoder (Primary/CLIP) Effective LR: 1.00e-04
#                          (Fallback to Main LR)
# 15:54:06-261659 INFO       - Text Encoder (T5XXL, if applicable) Effective LR:
#                          1.00e-04 (Fallback to Main LR)
# 15:54:06-262607 INFO       - U-Net Effective LR: 1.00e-04 (Specific Value)
# 15:54:06-263429 INFO     Note: These LRs reflect the GUI's direct settings.
#                          Advanced options in sd-scripts (e.g., block LRs, LoRA+)
#                          can further modify rates for specific layers.
# 15:54:06-285448 INFO     Saving training config to
#                          /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/
#                          Assignment08_SD_GEN/Qajar_LoRA_Model/last_20250621-1554
#                          06.json...
# 15:54:06-292258 INFO     Executing command: /usr/local/bin/accelerate launch
#                          --dynamo_backend no --dynamo_mode default
#                          --mixed_precision fp16 --num_processes 1 --num_machines
#                          1 --num_cpu_threads_per_process 2
#                          /content/kohya_ss/sd-scripts/train_network.py
#                          --config_file
#                          /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/
#                          Assignment08_SD_GEN/Qajar_LoRA_Model/config_lora-202506
#                          21-155406.toml
# 2025-06-21 15:54:19.041227: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750521259.064267    7475 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750521259.073591    7475 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1750521259.092839    7475 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750521259.092866    7475 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750521259.092870    7475 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750521259.092875    7475 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# /content/kohya_ss/sd-scripts/library/deepspeed_utils.py:131: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   wrap_model_forward_with_torch_autocast = args.mixed_precision is not "no"
# 2025-06-21 15:54:24 INFO     Using v1 tokenizer                ]8;id=915557;file:///content/kohya_ss/sd-scripts/library/strategy_sd.py\strategy_sd.py]8;;\:]8;id=81998;file:///content/kohya_ss/sd-scripts/library/strategy_sd.py#26\26]8;;\
# tokenizer_config.json: 100% 905/905 [00:00<00:00, 7.68MB/s]
# vocab.json: 100% 961k/961k [00:00<00:00, 1.44MB/s]
# merges.txt: 100% 525k/525k [00:00<00:00, 2.74MB/s]
# special_tokens_map.json: 100% 389/389 [00:00<00:00, 2.34MB/s]
# tokenizer.json: 100% 2.22M/2.22M [00:00<00:00, 10.5MB/s]
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 2025-06-21 15:54:26 INFO     Using DreamBooth method.       ]8;id=865300;file:///content/kohya_ss/sd-scripts/train_network.py\train_network.py]8;;\:]8;id=309985;file:///content/kohya_ss/sd-scripts/train_network.py#517\517]8;;\
#                     INFO     prepare images.                  ]8;id=193816;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=716569;file:///content/kohya_ss/sd-scripts/library/train_util.py#2072\2072]8;;\
#                     INFO     get image size from name of      ]8;id=887957;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=346260;file:///content/kohya_ss/sd-scripts/library/train_util.py#1965\1965]8;;\
#                              cache files
# 100% 19/19 [00:00<00:00, 184045.67it/s]
#                     INFO     set image size from cache files: ]8;id=279619;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=302865;file:///content/kohya_ss/sd-scripts/library/train_util.py#1995\1995]8;;\
#                              0/19
#                     INFO     found directory                  ]8;id=789676;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=628369;file:///content/kohya_ss/sd-scripts/library/train_util.py#2019\2019]8;;\
#                              /content/drive/MyDrive/Colab_Not
#                              ebooks/Computer_Vision/Assignmen
#                              t08_SD_GEN/qajar_images/001_qaja
#                              r contains 19 image files
# read caption: 100% 19/19 [00:03<00:00,  4.79it/s]
# 2025-06-21 15:54:30 INFO     19 train images with repeats.    ]8;id=896492;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=392573;file:///content/kohya_ss/sd-scripts/library/train_util.py#2116\2116]8;;\
#                     INFO     0 reg images with repeats.       ]8;id=303311;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=691523;file:///content/kohya_ss/sd-scripts/library/train_util.py#2120\2120]8;;\
#                     WARNING  no regularization images /       ]8;id=599070;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=162696;file:///content/kohya_ss/sd-scripts/library/train_util.py#2125\2125]8;;\
#                              正則化画像が見つかりませんでした
#                     INFO     [Dataset 0]                      ]8;id=545678;file:///content/kohya_ss/sd-scripts/library/config_util.py\config_util.py]8;;\:]8;id=621318;file:///content/kohya_ss/sd-scripts/library/config_util.py#580\580]8;;\
#                                batch_size: 1
#                                resolution: (512, 512)
#                                resize_interpolation: None
#                                enable_bucket: True
#                                min_bucket_reso: 256
#                                max_bucket_reso: 2048
#                                bucket_reso_steps: 64
#                                bucket_no_upscale: True
#
#                                [Subset 0 of Dataset 0]
#                                  image_dir:
#                              "/content/drive/MyDrive/Colab_No
#                              tebooks/Computer_Vision/Assignme
#                              nt08_SD_GEN/qajar_images/001_qaj
#                              ar"
#                                  image_count: 19
#                                  num_repeats: 1
#                                  shuffle_caption: False
#                                  keep_tokens: 0
#                                  caption_dropout_rate: 0.0
#                                  caption_dropout_every_n_epoc
#                              hs: 0
#                                  caption_tag_dropout_rate:
#                              0.0
#                                  caption_prefix: None
#                                  caption_suffix: None
#                                  color_aug: False
#                                  flip_aug: False
#                                  face_crop_aug_range: None
#                                  random_crop: False
#                                  token_warmup_min: 1,
#                                  token_warmup_step: 0,
#                                  alpha_mask: False
#                                  resize_interpolation: None
#                                  custom_attributes: {}
#                                  is_reg: False
#                                  class_tokens: qajar
#                                  caption_extension: .txt
#
#
#                     INFO     [Prepare dataset 0]              ]8;id=463247;file:///content/kohya_ss/sd-scripts/library/config_util.py\config_util.py]8;;\:]8;id=595089;file:///content/kohya_ss/sd-scripts/library/config_util.py#592\592]8;;\
#                     INFO     loading image sizes.              ]8;id=820280;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=664647;file:///content/kohya_ss/sd-scripts/library/train_util.py#987\987]8;;\
# 100% 19/19 [00:07<00:00,  2.59it/s]
# 2025-06-21 15:54:38 INFO     make buckets                     ]8;id=654511;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=200459;file:///content/kohya_ss/sd-scripts/library/train_util.py#1010\1010]8;;\
#                     WARNING  min_bucket_reso and              ]8;id=590418;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=544231;file:///content/kohya_ss/sd-scripts/library/train_util.py#1027\1027]8;;\
#                              max_bucket_reso are ignored if
#                              bucket_no_upscale is set,
#                              because bucket reso is defined
#                              by image size automatically /
#                              bucket_no_upscaleが指定された場
#                              合は、bucketの解像度は画像サイズ
#                              から自動計算されるため、min_buck
#                              et_resoとmax_bucket_resoは無視さ
#                              れます
#                     INFO     number of images (including      ]8;id=967066;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=325902;file:///content/kohya_ss/sd-scripts/library/train_util.py#1056\1056]8;;\
#                              repeats) /
#                              各bucketの画像枚数（繰り返し回数
#                              を含む）
#                     INFO     bucket 0: resolution (256, 448), ]8;id=801616;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=843393;file:///content/kohya_ss/sd-scripts/library/train_util.py#1061\1061]8;;\
#                              count: 1
#                     INFO     bucket 1: resolution (320, 576), ]8;id=196546;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=243107;file:///content/kohya_ss/sd-scripts/library/train_util.py#1061\1061]8;;\
#                              count: 2
#                     INFO     bucket 2: resolution (320, 640), ]8;id=816385;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=278305;file:///content/kohya_ss/sd-scripts/library/train_util.py#1061\1061]8;;\
#                              count: 1
#                     INFO     bucket 3: resolution (384, 512), ]8;id=577703;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=483504;file:///content/kohya_ss/sd-scripts/library/train_util.py#1061\1061]8;;\
#                              count: 4
#                     INFO     bucket 4: resolution (384, 576), ]8;id=389074;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=890717;file:///content/kohya_ss/sd-scripts/library/train_util.py#1061\1061]8;;\
#                              count: 6
#                     INFO     bucket 5: resolution (384, 640), ]8;id=455182;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=549635;file:///content/kohya_ss/sd-scripts/library/train_util.py#1061\1061]8;;\
#                              count: 1
#                     INFO     bucket 6: resolution (448, 320), ]8;id=212933;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=717234;file:///content/kohya_ss/sd-scripts/library/train_util.py#1061\1061]8;;\
#                              count: 1
#                     INFO     bucket 7: resolution (448, 448), ]8;id=323649;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=222406;file:///content/kohya_ss/sd-scripts/library/train_util.py#1061\1061]8;;\
#                              count: 1
#                     INFO     bucket 8: resolution (512, 384), ]8;id=762430;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=563120;file:///content/kohya_ss/sd-scripts/library/train_util.py#1061\1061]8;;\
#                              count: 1
#                     INFO     bucket 9: resolution (512, 512), ]8;id=690338;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=638116;file:///content/kohya_ss/sd-scripts/library/train_util.py#1061\1061]8;;\
#                              count: 1
#                     INFO     mean ar error (without repeats): ]8;id=225300;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=129605;file:///content/kohya_ss/sd-scripts/library/train_util.py#1069\1069]8;;\
#                              0.01883726731195247
#                     INFO     preparing accelerator          ]8;id=957361;file:///content/kohya_ss/sd-scripts/train_network.py\train_network.py]8;;\:]8;id=214410;file:///content/kohya_ss/sd-scripts/train_network.py#580\580]8;;\
# accelerator device: cuda
#                     INFO     loading model for process 0/1    ]8;id=273145;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=65304;file:///content/kohya_ss/sd-scripts/library/train_util.py#5481\5481]8;;\
#                     INFO     load Diffusers pretrained        ]8;id=97802;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=754665;file:///content/kohya_ss/sd-scripts/library/train_util.py#5443\5443]8;;\
#                              models:
#                              runwayml/stable-diffusion-v1-5
# model_index.json: 100% 541/541 [00:00<00:00, 3.94MB/s]
# Fetching 9 files:   0% 0/9 [00:00<?, ?it/s]
# model.safetensors:   0% 0.00/492M [00:00<?, ?B/s]
#
# diffusion_pytorch_model.safetensors:   0% 0.00/335M [00:00<?, ?B/s]
#
#
# preprocessor_config.json: 100% 342/342 [00:00<00:00, 2.58MB/s]
# Fetching 9 files:  11% 1/9 [00:00<00:02,  3.79it/s]
#
#
# config.json: 100% 617/617 [00:00<00:00, 3.75MB/s]
#
#
#
# scheduler_config.json: 100% 308/308 [00:00<00:00, 2.43MB/s]
#
#
#
# config.json: 100% 743/743 [00:00<00:00, 6.10MB/s]
#
#
# diffusion_pytorch_model.safetensors:   3% 10.5M/335M [00:00<00:04, 76.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:   0% 0.00/3.44G [00:00<?, ?B/s]
# model.safetensors:   2% 10.5M/492M [00:00<00:06, 70.4MB/s]
#
#
#
# config.json: 100% 547/547 [00:00<00:00, 3.52MB/s]
#
#
# diffusion_pytorch_model.safetensors:   9% 31.5M/335M [00:00<00:02, 112MB/s]
# model.safetensors:   6% 31.5M/492M [00:00<00:04, 109MB/s]
#
#
# diffusion_pytorch_model.safetensors:   0% 10.5M/3.44G [00:00<01:32, 37.2MB/s]
# model.safetensors:  11% 52.4M/492M [00:00<00:03, 111MB/s]
#
# diffusion_pytorch_model.safetensors:  16% 52.4M/335M [00:00<00:02, 109MB/s]
#
#
# diffusion_pytorch_model.safetensors:   1% 21.0M/3.44G [00:00<01:10, 48.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:   1% 31.5M/3.44G [00:00<00:54, 63.0MB/s]
#
# diffusion_pytorch_model.safetensors:  22% 73.4M/335M [00:00<00:02, 95.2MB/s]
# model.safetensors:  15% 73.4M/492M [00:00<00:04, 94.2MB/s]
#
#
# diffusion_pytorch_model.safetensors:   1% 41.9M/3.44G [00:00<00:47, 71.9MB/s]
# model.safetensors:  17% 83.9M/492M [00:00<00:04, 94.5MB/s]
#
# diffusion_pytorch_model.safetensors:  25% 83.9M/335M [00:00<00:02, 89.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:   2% 52.4M/3.44G [00:00<00:45, 75.1MB/s]
# model.safetensors:  19% 94.4M/492M [00:01<00:04, 88.9MB/s]
#
# diffusion_pytorch_model.safetensors:  28% 94.4M/335M [00:01<00:02, 88.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:   2% 62.9M/3.44G [00:00<00:42, 79.4MB/s]
# model.safetensors:  21% 105M/492M [00:01<00:04, 90.4MB/s]
#
# diffusion_pytorch_model.safetensors:  31% 105M/335M [00:01<00:02, 87.5MB/s]
# model.safetensors:  23% 115M/492M [00:01<00:04, 90.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:   2% 83.9M/3.44G [00:01<00:37, 89.5MB/s]
#
# diffusion_pytorch_model.safetensors:  38% 126M/335M [00:01<00:02, 91.8MB/s]
# model.safetensors:  26% 126M/492M [00:01<00:04, 88.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:   3% 94.4M/3.44G [00:01<00:37, 89.8MB/s]
# model.safetensors:  28% 136M/492M [00:01<00:03, 90.7MB/s]
#
# diffusion_pytorch_model.safetensors:  41% 136M/335M [00:01<00:02, 91.7MB/s]
#
#
# diffusion_pytorch_model.safetensors:   3% 105M/3.44G [00:01<00:38, 86.0MB/s]
# model.safetensors:  30% 147M/492M [00:01<00:03, 93.4MB/s]
#
# diffusion_pytorch_model.safetensors:  44% 147M/335M [00:01<00:02, 92.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:   4% 126M/3.44G [00:01<00:31, 104MB/s]
#
# diffusion_pytorch_model.safetensors:  47% 157M/335M [00:01<00:01, 91.7MB/s]
# model.safetensors:  34% 168M/492M [00:01<00:03, 95.1MB/s]
#
# diffusion_pytorch_model.safetensors:  50% 168M/335M [00:01<00:01, 92.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:   4% 136M/3.44G [00:01<00:33, 99.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:   4% 147M/3.44G [00:01<00:33, 97.2MB/s]
# model.safetensors:  36% 178M/492M [00:01<00:03, 93.3MB/s]
#
# diffusion_pytorch_model.safetensors:  56% 189M/335M [00:02<00:01, 97.1MB/s]
# model.safetensors:  38% 189M/492M [00:02<00:03, 91.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:   5% 157M/3.44G [00:01<00:36, 88.9MB/s]
#
# diffusion_pytorch_model.safetensors:  60% 199M/335M [00:02<00:01, 95.9MB/s]
# model.safetensors:  40% 199M/492M [00:02<00:03, 93.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:   5% 178M/3.44G [00:02<00:32, 99.0MB/s]
#
# diffusion_pytorch_model.safetensors:  63% 210M/335M [00:02<00:01, 94.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:   5% 189M/3.44G [00:02<00:33, 96.7MB/s]
# model.safetensors:  45% 220M/492M [00:02<00:02, 94.1MB/s]
#
# diffusion_pytorch_model.safetensors:  66% 220M/335M [00:02<00:01, 86.8MB/s]
#
# diffusion_pytorch_model.safetensors:  69% 231M/335M [00:02<00:01, 85.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:   6% 210M/3.44G [00:02<00:32, 99.1MB/s]
# model.safetensors:  49% 241M/492M [00:02<00:02, 97.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:   6% 220M/3.44G [00:02<00:32, 98.8MB/s]
#
# diffusion_pytorch_model.safetensors:  75% 252M/335M [00:02<00:00, 92.2MB/s]
# model.safetensors:  53% 262M/492M [00:02<00:02, 92.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:   7% 241M/3.44G [00:02<00:31, 100MB/s]
#
#
# diffusion_pytorch_model.safetensors:   7% 252M/3.44G [00:03<01:47, 29.7MB/s]
# model.safetensors:  55% 273M/492M [00:04<00:07, 29.5MB/s]
#
# diffusion_pytorch_model.safetensors:  81% 273M/335M [00:04<00:02, 29.5MB/s]
# model.safetensors:  58% 283M/492M [00:04<00:06, 34.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:   8% 273M/3.44G [00:04<01:15, 42.1MB/s]
#
# diffusion_pytorch_model.safetensors:  85% 283M/335M [00:04<00:01, 33.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:   9% 294M/3.44G [00:04<00:54, 57.3MB/s]
# model.safetensors:  62% 304M/492M [00:04<00:03, 47.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:   9% 315M/3.44G [00:04<00:43, 71.9MB/s]
#
# diffusion_pytorch_model.safetensors:  91% 304M/335M [00:04<00:00, 45.6MB/s]
# model.safetensors:  66% 325M/492M [00:04<00:02, 61.8MB/s]
#
# diffusion_pytorch_model.safetensors:  94% 315M/335M [00:04<00:00, 51.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:  10% 336M/3.44G [00:04<00:36, 85.4MB/s]
# model.safetensors:  70% 346M/492M [00:04<00:01, 75.0MB/s]
#
# diffusion_pytorch_model.safetensors:  97% 325M/335M [00:04<00:00, 55.1MB/s]
#
#
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:04<00:00, 68.2MB/s]
#
# model.safetensors:  75% 367M/492M [00:04<00:01, 82.7MB/s]
#
#
# diffusion_pytorch_model.safetensors:  11% 377M/3.44G [00:04<00:27, 113MB/s]
# model.safetensors:  79% 388M/492M [00:05<00:01, 98.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:  12% 398M/3.44G [00:04<00:24, 122MB/s]
#
#
# diffusion_pytorch_model.safetensors:  12% 419M/3.44G [00:05<00:23, 127MB/s]
# model.safetensors:  83% 409M/492M [00:05<00:00, 96.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:  13% 440M/3.44G [00:05<00:21, 142MB/s]
# model.safetensors:  87% 430M/492M [00:05<00:00, 107MB/s]
#
#
# diffusion_pytorch_model.safetensors:  13% 461M/3.44G [00:05<00:19, 155MB/s]
# model.safetensors:  92% 451M/492M [00:05<00:00, 119MB/s]
#
#
# diffusion_pytorch_model.safetensors:  14% 482M/3.44G [00:05<00:19, 154MB/s]
# model.safetensors:  96% 472M/492M [00:05<00:00, 124MB/s]
#
#
# diffusion_pytorch_model.safetensors:  15% 503M/3.44G [00:05<00:19, 154MB/s]
# model.safetensors: 100% 492M/492M [00:05<00:00, 123MB/s]
#
#
# model.safetensors: 100% 492M/492M [00:05<00:00, 82.9MB/s]
# Fetching 9 files:  56% 5/9 [00:06<00:05,  1.30s/it]
#
#
# diffusion_pytorch_model.safetensors:  16% 545M/3.44G [00:05<00:19, 149MB/s]
#
#
# diffusion_pytorch_model.safetensors:  17% 577M/3.44G [00:06<00:16, 174MB/s]
#
#
# diffusion_pytorch_model.safetensors:  17% 598M/3.44G [00:06<00:16, 175MB/s]
#
#
# diffusion_pytorch_model.safetensors:  18% 629M/3.44G [00:06<00:14, 198MB/s]
#
#
# diffusion_pytorch_model.safetensors:  19% 661M/3.44G [00:06<00:12, 216MB/s]
#
#
# diffusion_pytorch_model.safetensors:  20% 692M/3.44G [00:06<00:11, 230MB/s]
#
#
# diffusion_pytorch_model.safetensors:  21% 724M/3.44G [00:06<00:11, 238MB/s]
#
#
# diffusion_pytorch_model.safetensors:  22% 755M/3.44G [00:06<00:11, 238MB/s]
#
#
# diffusion_pytorch_model.safetensors:  23% 786M/3.44G [00:06<00:10, 245MB/s]
#
#
# diffusion_pytorch_model.safetensors:  24% 818M/3.44G [00:07<00:10, 247MB/s]
#
#
# diffusion_pytorch_model.safetensors:  25% 849M/3.44G [00:07<00:10, 250MB/s]
#
#
# diffusion_pytorch_model.safetensors:  26% 881M/3.44G [00:07<00:10, 253MB/s]
#
#
# diffusion_pytorch_model.safetensors:  27% 912M/3.44G [00:08<00:40, 61.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:  27% 933M/3.44G [00:08<00:34, 71.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:  28% 965M/3.44G [00:08<00:26, 92.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:  29% 986M/3.44G [00:10<00:57, 42.6MB/s]
#
#
# diffusion_pytorch_model.safetensors:  29% 1.01G/3.44G [00:10<00:46, 52.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:  30% 1.03G/3.44G [00:11<01:08, 35.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  30% 1.05G/3.44G [00:11<00:53, 44.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  31% 1.08G/3.44G [00:13<01:11, 32.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:  32% 1.09G/3.44G [00:13<01:04, 36.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:  32% 1.11G/3.44G [00:13<00:49, 47.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  33% 1.13G/3.44G [00:13<00:37, 61.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  34% 1.16G/3.44G [00:13<00:25, 87.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:  34% 1.18G/3.44G [00:13<00:22, 102MB/s]
#
#
# diffusion_pytorch_model.safetensors:  35% 1.21G/3.44G [00:13<00:19, 115MB/s]
#
#
# diffusion_pytorch_model.safetensors:  36% 1.23G/3.44G [00:13<00:17, 129MB/s]
#
#
# diffusion_pytorch_model.safetensors:  37% 1.26G/3.44G [00:14<00:14, 154MB/s]
#
#
# diffusion_pytorch_model.safetensors:  38% 1.29G/3.44G [00:14<00:12, 175MB/s]
#
#
# diffusion_pytorch_model.safetensors:  38% 1.32G/3.44G [00:14<00:11, 189MB/s]
#
#
# diffusion_pytorch_model.safetensors:  39% 1.35G/3.44G [00:14<00:10, 194MB/s]
#
#
# diffusion_pytorch_model.safetensors:  40% 1.38G/3.44G [00:14<00:10, 198MB/s]
#
#
# diffusion_pytorch_model.safetensors:  41% 1.41G/3.44G [00:14<00:10, 200MB/s]
#
#
# diffusion_pytorch_model.safetensors:  42% 1.44G/3.44G [00:14<00:09, 213MB/s]
#
#
# diffusion_pytorch_model.safetensors:  43% 1.47G/3.44G [00:14<00:08, 225MB/s]
#
#
# diffusion_pytorch_model.safetensors:  44% 1.50G/3.44G [00:15<00:09, 206MB/s]
#
#
# diffusion_pytorch_model.safetensors:  45% 1.53G/3.44G [00:15<00:15, 122MB/s]
#
#
# diffusion_pytorch_model.safetensors:  45% 1.55G/3.44G [00:15<00:16, 113MB/s]
#
#
# diffusion_pytorch_model.safetensors:  46% 1.58G/3.44G [00:15<00:13, 135MB/s]
#
#
# diffusion_pytorch_model.safetensors:  47% 1.60G/3.44G [00:17<00:39, 46.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  47% 1.63G/3.44G [00:17<00:31, 57.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  48% 1.66G/3.44G [00:17<00:23, 77.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  49% 1.69G/3.44G [00:17<00:17, 100MB/s]
#
#
# diffusion_pytorch_model.safetensors:  50% 1.72G/3.44G [00:17<00:14, 122MB/s]
#
#
# diffusion_pytorch_model.safetensors:  51% 1.74G/3.44G [00:18<00:12, 133MB/s]
#
#
# diffusion_pytorch_model.safetensors:  52% 1.77G/3.44G [00:18<00:10, 156MB/s]
#
#
# diffusion_pytorch_model.safetensors:  52% 1.80G/3.44G [00:19<00:31, 52.7MB/s]
#
#
# diffusion_pytorch_model.safetensors:  53% 1.84G/3.44G [00:19<00:22, 69.8MB/s]
#
#
# diffusion_pytorch_model.safetensors:  54% 1.87G/3.44G [00:19<00:17, 90.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  55% 1.90G/3.44G [00:19<00:13, 111MB/s]
#
#
# diffusion_pytorch_model.safetensors:  56% 1.93G/3.44G [00:20<00:11, 135MB/s]
#
#
# diffusion_pytorch_model.safetensors:  57% 1.96G/3.44G [00:20<00:09, 156MB/s]
#
#
# diffusion_pytorch_model.safetensors:  58% 1.99G/3.44G [00:20<00:08, 176MB/s]
#
#
# diffusion_pytorch_model.safetensors:  59% 2.02G/3.44G [00:20<00:07, 190MB/s]
#
#
# diffusion_pytorch_model.safetensors:  60% 2.06G/3.44G [00:20<00:07, 173MB/s]
#
#
# diffusion_pytorch_model.safetensors:  61% 2.09G/3.44G [00:20<00:06, 195MB/s]
#
#
# diffusion_pytorch_model.safetensors:  62% 2.12G/3.44G [00:20<00:06, 211MB/s]
#
#
# diffusion_pytorch_model.safetensors:  63% 2.15G/3.44G [00:21<00:05, 224MB/s]
#
#
# diffusion_pytorch_model.safetensors:  63% 2.18G/3.44G [00:21<00:05, 230MB/s]
#
#
# diffusion_pytorch_model.safetensors:  64% 2.21G/3.44G [00:21<00:05, 242MB/s]
#
#
# diffusion_pytorch_model.safetensors:  65% 2.24G/3.44G [00:21<00:04, 251MB/s]
#
#
# diffusion_pytorch_model.safetensors:  66% 2.28G/3.44G [00:21<00:05, 209MB/s]
#
#
# diffusion_pytorch_model.safetensors:  67% 2.31G/3.44G [00:21<00:05, 191MB/s]
#
#
# diffusion_pytorch_model.safetensors:  68% 2.33G/3.44G [00:25<00:46, 23.9MB/s]
#
#
# diffusion_pytorch_model.safetensors:  68% 2.35G/3.44G [00:25<00:35, 30.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:  69% 2.38G/3.44G [00:25<00:24, 43.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:  70% 2.41G/3.44G [00:25<00:17, 59.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:  71% 2.43G/3.44G [00:26<00:16, 61.3MB/s]
#
#
# diffusion_pytorch_model.safetensors:  72% 2.46G/3.44G [00:26<00:11, 81.5MB/s]
#
#
# diffusion_pytorch_model.safetensors:  73% 2.50G/3.44G [00:26<00:09, 105MB/s]
#
#
# diffusion_pytorch_model.safetensors:  74% 2.53G/3.44G [00:26<00:07, 130MB/s]
#
#
# diffusion_pytorch_model.safetensors:  74% 2.56G/3.44G [00:26<00:05, 153MB/s]
#
#
# diffusion_pytorch_model.safetensors:  75% 2.59G/3.44G [00:26<00:07, 115MB/s]
#
#
# diffusion_pytorch_model.safetensors:  76% 2.62G/3.44G [00:27<00:06, 132MB/s]
#
#
# diffusion_pytorch_model.safetensors:  77% 2.65G/3.44G [00:27<00:05, 154MB/s]
#
#
# diffusion_pytorch_model.safetensors:  78% 2.68G/3.44G [00:27<00:04, 171MB/s]
#
#
# diffusion_pytorch_model.safetensors:  79% 2.72G/3.44G [00:27<00:03, 187MB/s]
#
#
# diffusion_pytorch_model.safetensors:  80% 2.75G/3.44G [00:28<00:11, 59.4MB/s]
#
#
# diffusion_pytorch_model.safetensors:  81% 2.77G/3.44G [00:29<00:09, 67.1MB/s]
#
#
# diffusion_pytorch_model.safetensors:  81% 2.80G/3.44G [00:29<00:07, 87.0MB/s]
#
#
# diffusion_pytorch_model.safetensors:  82% 2.83G/3.44G [00:29<00:05, 111MB/s]
#
#
# diffusion_pytorch_model.safetensors:  83% 2.86G/3.44G [00:29<00:04, 128MB/s]
#
#
# diffusion_pytorch_model.safetensors:  84% 2.89G/3.44G [00:29<00:03, 151MB/s]
#
#
# diffusion_pytorch_model.safetensors:  85% 2.93G/3.44G [00:29<00:02, 178MB/s]
#
#
# diffusion_pytorch_model.safetensors:  86% 2.96G/3.44G [00:29<00:02, 198MB/s]
#
#
# diffusion_pytorch_model.safetensors:  87% 2.99G/3.44G [00:29<00:02, 206MB/s]
#
#
# diffusion_pytorch_model.safetensors:  88% 3.02G/3.44G [00:30<00:01, 210MB/s]
#
#
# diffusion_pytorch_model.safetensors:  89% 3.05G/3.44G [00:30<00:01, 218MB/s]
#
#
# diffusion_pytorch_model.safetensors:  90% 3.08G/3.44G [00:30<00:01, 228MB/s]
#
#
# diffusion_pytorch_model.safetensors:  91% 3.11G/3.44G [00:30<00:01, 238MB/s]
#
#
# diffusion_pytorch_model.safetensors:  91% 3.15G/3.44G [00:30<00:01, 212MB/s]
#
#
# diffusion_pytorch_model.safetensors:  92% 3.18G/3.44G [00:30<00:01, 168MB/s]
#
#
# diffusion_pytorch_model.safetensors:  93% 3.21G/3.44G [00:31<00:01, 179MB/s]
#
#
# diffusion_pytorch_model.safetensors:  94% 3.23G/3.44G [00:31<00:01, 182MB/s]
#
#
# diffusion_pytorch_model.safetensors:  95% 3.26G/3.44G [00:31<00:00, 185MB/s]
#
#
# diffusion_pytorch_model.safetensors:  96% 3.29G/3.44G [00:31<00:00, 207MB/s]
#
#
# diffusion_pytorch_model.safetensors:  97% 3.32G/3.44G [00:31<00:00, 216MB/s]
#
#
# diffusion_pytorch_model.safetensors:  98% 3.36G/3.44G [00:31<00:00, 225MB/s]
#
#
# diffusion_pytorch_model.safetensors:  99% 3.39G/3.44G [00:31<00:00, 227MB/s]
#
#
# diffusion_pytorch_model.safetensors: 100% 3.44G/3.44G [00:32<00:00, 107MB/s]
# Fetching 9 files: 100% 9/9 [00:32<00:00,  3.61s/it]
# Loading pipeline components...: 100% 5/5 [00:01<00:00,  3.54it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# 2025-06-21 15:55:12 INFO     UNet2DConditionModel: 64, 8,  ]8;id=655638;file:///content/kohya_ss/sd-scripts/library/original_unet.py\original_unet.py]8;;\:]8;id=1198;file:///content/kohya_ss/sd-scripts/library/original_unet.py#1387\1387]8;;\
#                              768, False, False
# 2025-06-21 15:55:36 INFO     U-Net converted to original      ]8;id=255759;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=765752;file:///content/kohya_ss/sd-scripts/library/train_util.py#5468\5468]8;;\
#                              U-Net
#                     INFO     Enable xformers for U-Net        ]8;id=961564;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=595078;file:///content/kohya_ss/sd-scripts/library/train_util.py#3349\3349]8;;\
# import network module: networks.lora
# 2025-06-21 15:55:38 INFO     [Dataset 0]                      ]8;id=569366;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=469730;file:///content/kohya_ss/sd-scripts/library/train_util.py#2613\2613]8;;\
#                     INFO     caching latents with caching     ]8;id=978147;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=513054;file:///content/kohya_ss/sd-scripts/library/train_util.py#1115\1115]8;;\
#                              strategy.
#                     INFO     caching latents...               ]8;id=130873;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=574033;file:///content/kohya_ss/sd-scripts/library/train_util.py#1164\1164]8;;\
# 100% 19/19 [00:12<00:00,  1.57it/s]
# 2025-06-21 15:55:53 INFO     create LoRA network. base dim (rank):   ]8;id=632485;file:///content/kohya_ss/sd-scripts/networks/lora.py\lora.py]8;;\:]8;id=573812;file:///content/kohya_ss/sd-scripts/networks/lora.py#935\935]8;;\
#                              8, alpha: 1
#                     INFO     neuron dropout: p=None, rank dropout:   ]8;id=836695;file:///content/kohya_ss/sd-scripts/networks/lora.py\lora.py]8;;\:]8;id=403598;file:///content/kohya_ss/sd-scripts/networks/lora.py#936\936]8;;\
#                              p=None, module dropout: p=None
#                     INFO     create LoRA for Text Encoder:          ]8;id=198591;file:///content/kohya_ss/sd-scripts/networks/lora.py\lora.py]8;;\:]8;id=861370;file:///content/kohya_ss/sd-scripts/networks/lora.py#1030\1030]8;;\
#                     INFO     create LoRA for Text Encoder: 72       ]8;id=499678;file:///content/kohya_ss/sd-scripts/networks/lora.py\lora.py]8;;\:]8;id=72441;file:///content/kohya_ss/sd-scripts/networks/lora.py#1035\1035]8;;\
#                              modules.
#                     INFO     create LoRA for U-Net: 192 modules.    ]8;id=156814;file:///content/kohya_ss/sd-scripts/networks/lora.py\lora.py]8;;\:]8;id=968235;file:///content/kohya_ss/sd-scripts/networks/lora.py#1043\1043]8;;\
#                     INFO     enable LoRA for U-Net: 192 modules     ]8;id=967922;file:///content/kohya_ss/sd-scripts/networks/lora.py\lora.py]8;;\:]8;id=869647;file:///content/kohya_ss/sd-scripts/networks/lora.py#1089\1089]8;;\
# prepare optimizer, data loader etc.
#                     INFO     use 8-bit AdamW optimizer | {}   ]8;id=550055;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=289023;file:///content/kohya_ss/sd-scripts/library/train_util.py#4804\4804]8;;\
# running training / 学習開始
#   num train images * repeats / 学習画像の数×繰り返し回数: 19
#   num validation images * repeats / 学習画像の数×繰り返し回数: 0
#   num reg images / 正則化画像の数: 0
#   num batches per epoch / 1epochのバッチ数: 19
#   num epochs / epoch数: 85
#   batch size per device / バッチサイズ: 1
#   gradient accumulation steps / 勾配を合計するステップ数 = 1
#   total optimization steps / 学習ステップ数: 1600
# 2025-06-21 15:55:55 INFO     unet dtype: torch.float16,    ]8;id=938516;file:///content/kohya_ss/sd-scripts/train_network.py\train_network.py]8;;\:]8;id=712480;file:///content/kohya_ss/sd-scripts/train_network.py#1323\1323]8;;\
#                              device: cuda:0
#                     INFO     text_encoder [0] dtype:       ]8;id=288579;file:///content/kohya_ss/sd-scripts/train_network.py\train_network.py]8;;\:]8;id=472449;file:///content/kohya_ss/sd-scripts/train_network.py#1329\1329]8;;\
#                              torch.float16, device: cuda:0
# steps:   0% 0/1600 [00:00<?, ?it/s]
# epoch 1/85
#
# 2025-06-21 15:55:56 INFO     epoch is incremented.             ]8;id=831861;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=374727;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 0, epoch: 1
# steps:   1% 19/1600 [00:09<13:24,  1.97it/s, avr_loss=0.181]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000001.safetensors
#
# epoch 2/85
#
# ...
# steps:  66% 1064/1600 [05:39<02:50,  3.14it/s, avr_loss=0.153]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000056.safetensors
#
# epoch 57/85
#
# 2025-06-21 16:01:35 INFO     epoch is incremented.             ]8;id=520599;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=785228;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 56, epoch: 57
# steps:  68% 1083/1600 [05:45<02:45,  3.13it/s, avr_loss=0.135]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000057.safetensors
#
# epoch 58/85
#
# 2025-06-21 16:01:42 INFO     epoch is incremented.             ]8;id=70744;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=953916;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 57, epoch: 58
# steps:  69% 1102/1600 [05:51<02:38,  3.14it/s, avr_loss=0.181]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000058.safetensors
#
# epoch 59/85
#
# 2025-06-21 16:01:47 INFO     epoch is incremented.             ]8;id=6240;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=238865;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 58, epoch: 59
# steps:  70% 1121/1600 [05:57<02:32,  3.14it/s, avr_loss=0.231]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000059.safetensors
#
# epoch 60/85
#
# 2025-06-21 16:01:53 INFO     epoch is incremented.             ]8;id=640822;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=521700;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 59, epoch: 60
# steps:  71% 1140/1600 [06:03<02:26,  3.14it/s, avr_loss=0.143]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000060.safetensors
#
# epoch 61/85
#
# 2025-06-21 16:02:00 INFO     epoch is incremented.             ]8;id=19610;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=105804;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 60, epoch: 61
# steps:  72% 1159/1600 [06:09<02:20,  3.14it/s, avr_loss=0.121]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000061.safetensors
#
# epoch 62/85
#
# 2025-06-21 16:02:06 INFO     epoch is incremented.             ]8;id=262962;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=4237;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 61, epoch: 62
# steps:  74% 1178/1600 [06:16<02:14,  3.13it/s, avr_loss=0.153]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000062.safetensors
#
# epoch 63/85
#
# 2025-06-21 16:02:12 INFO     epoch is incremented.             ]8;id=460081;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=755203;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 62, epoch: 63
# steps:  75% 1197/1600 [06:21<02:08,  3.14it/s, avr_loss=0.151]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000063.safetensors
#
# epoch 64/85
#
# 2025-06-21 16:02:17 INFO     epoch is incremented.             ]8;id=145836;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=726031;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 63, epoch: 64
# steps:  76% 1216/1600 [06:28<02:02,  3.13it/s, avr_loss=0.163]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000064.safetensors
#
# epoch 65/85
#
# 2025-06-21 16:02:24 INFO     epoch is incremented.             ]8;id=204972;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=783171;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 64, epoch: 65
# steps:  77% 1235/1600 [06:33<01:56,  3.14it/s, avr_loss=0.145]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000065.safetensors
#
# epoch 66/85
#
# 2025-06-21 16:02:30 INFO     epoch is incremented.             ]8;id=679641;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=689065;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 65, epoch: 66
# steps:  78% 1254/1600 [06:40<01:50,  3.13it/s, avr_loss=0.218]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000066.safetensors
#
# epoch 67/85
#
# 2025-06-21 16:02:36 INFO     epoch is incremented.             ]8;id=703228;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=604604;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 66, epoch: 67
# steps:  80% 1273/1600 [06:46<01:44,  3.13it/s, avr_loss=0.151]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000067.safetensors
#
# epoch 68/85
#
# 2025-06-21 16:02:42 INFO     epoch is incremented.             ]8;id=927785;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=323703;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 67, epoch: 68
# steps:  81% 1292/1600 [06:52<01:38,  3.13it/s, avr_loss=0.167]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000068.safetensors
#
# epoch 69/85
#
# 2025-06-21 16:02:48 INFO     epoch is incremented.             ]8;id=55454;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=821330;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 68, epoch: 69
# steps:  82% 1311/1600 [06:58<01:32,  3.13it/s, avr_loss=0.2]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000069.safetensors
#
# epoch 70/85
#
# 2025-06-21 16:02:54 INFO     epoch is incremented.             ]8;id=244113;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=398132;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 69, epoch: 70
# steps:  83% 1330/1600 [07:04<01:26,  3.14it/s, avr_loss=0.16]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000070.safetensors
#
# epoch 71/85
#
# 2025-06-21 16:03:00 INFO     epoch is incremented.             ]8;id=443834;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=112236;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 70, epoch: 71
# steps:  84% 1349/1600 [07:10<01:20,  3.13it/s, avr_loss=0.168]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000071.safetensors
#
# epoch 72/85
#
# 2025-06-21 16:03:07 INFO     epoch is incremented.             ]8;id=333093;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=7629;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 71, epoch: 72
# steps:  86% 1368/1600 [07:16<01:13,  3.14it/s, avr_loss=0.0979]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000072.safetensors
#
# epoch 73/85
#
# 2025-06-21 16:03:12 INFO     epoch is incremented.             ]8;id=684257;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=162943;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 72, epoch: 73
# steps:  87% 1387/1600 [07:23<01:08,  3.13it/s, avr_loss=0.147]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000073.safetensors
#
# epoch 74/85
#
# 2025-06-21 16:03:19 INFO     epoch is incremented.             ]8;id=383753;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=232512;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 73, epoch: 74
# steps:  88% 1406/1600 [07:28<01:01,  3.13it/s, avr_loss=0.179]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000074.safetensors
#
# epoch 75/85
#
# 2025-06-21 16:03:24 INFO     epoch is incremented.             ]8;id=636236;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=101893;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 74, epoch: 75
# steps:  89% 1425/1600 [07:35<00:55,  3.13it/s, avr_loss=0.225]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000075.safetensors
#
# epoch 76/85
#
# 2025-06-21 16:03:31 INFO     epoch is incremented.             ]8;id=590094;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=183581;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 75, epoch: 76
# steps:  90% 1444/1600 [07:41<00:49,  3.13it/s, avr_loss=0.0614]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000076.safetensors
#
# epoch 77/85
#
# 2025-06-21 16:03:37 INFO     epoch is incremented.             ]8;id=620313;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=147402;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 76, epoch: 77
# steps:  91% 1463/1600 [07:47<00:43,  3.13it/s, avr_loss=0.17]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000077.safetensors
#
# epoch 78/85
#
# 2025-06-21 16:03:43 INFO     epoch is incremented.             ]8;id=184611;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=252465;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 77, epoch: 78
# steps:  93% 1482/1600 [07:53<00:37,  3.13it/s, avr_loss=0.181]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000078.safetensors
#
# epoch 79/85
#
# 2025-06-21 16:03:49 INFO     epoch is incremented.             ]8;id=713147;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=919651;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 78, epoch: 79
# steps:  94% 1501/1600 [07:58<00:31,  3.13it/s, avr_loss=0.155]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000079.safetensors
#
# epoch 80/85
#
# 2025-06-21 16:03:55 INFO     epoch is incremented.             ]8;id=757311;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=8993;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 79, epoch: 80
# steps:  95% 1520/1600 [08:05<00:25,  3.13it/s, avr_loss=0.161]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000080.safetensors
#
# epoch 81/85
#
# 2025-06-21 16:04:01 INFO     epoch is incremented.             ]8;id=993456;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=543779;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 80, epoch: 81
# steps:  96% 1539/1600 [08:11<00:19,  3.13it/s, avr_loss=0.166]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000081.safetensors
#
# epoch 82/85
#
# 2025-06-21 16:04:07 INFO     epoch is incremented.             ]8;id=276430;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=684107;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 81, epoch: 82
# steps:  97% 1558/1600 [08:17<00:13,  3.13it/s, avr_loss=0.0972]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000082.safetensors
#
# epoch 83/85
#
# 2025-06-21 16:04:13 INFO     epoch is incremented.             ]8;id=521718;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=224811;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 82, epoch: 83
# steps:  99% 1577/1600 [08:23<00:07,  3.13it/s, avr_loss=0.161]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000083.safetensors
#
# epoch 84/85
#
# 2025-06-21 16:04:19 INFO     epoch is incremented.             ]8;id=62590;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=461240;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 83, epoch: 84
# steps: 100% 1596/1600 [08:29<00:01,  3.13it/s, avr_loss=0.12]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last-000084.safetensors
#
# epoch 85/85
#
# 2025-06-21 16:04:26 INFO     epoch is incremented.             ]8;id=241398;file:///content/kohya_ss/sd-scripts/library/train_util.py\train_util.py]8;;\:]8;id=551159;file:///content/kohya_ss/sd-scripts/library/train_util.py#779\779]8;;\
#                              current_epoch: 84, epoch: 85
# steps: 100% 1600/1600 [08:31<00:00,  3.13it/s, avr_loss=0.133]
# saving checkpoint: /content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last.safetensors
# 2025-06-21 16:04:27 INFO     model saved.                  ]8;id=271579;file:///content/kohya_ss/sd-scripts/train_network.py\train_network.py]8;;\:]8;id=50793;file:///content/kohya_ss/sd-scripts/train_network.py#1703\1703]8;;\
# steps: 100% 1600/1600 [08:31<00:00,  3.13it/s, avr_loss=0.133]
# 16:04:35-702234 INFO     Training has ended.
# Keyboard interruption in main thread... closing server.
# ^C

# %% [markdown]
# # Step 2: Inference and Comparison (Code)
#
# * This cell loads the base Stable Diffusion v1.5 model and your newly trained LoRA.
#
# * It then generates two images: one with the base model and one with the LoRA activated.
#
# * This allows for a direct comparison of their outputs using the same seed.

# %% [markdown]
# ## code snippet 1

# %%
import torch
from diffusers import StableDiffusionPipeline
from PIL import Image

# --- Configuration ---
base_model_id = "runwayml/stable-diffusion-v1-5"

lora_path = "/content/last.safetensors"

# --- End Configuration ---

print("Loading base model pipeline...")
# Use torch.float16 for faster inference and lower memory usage on compatible GPUs
pipe = StableDiffusionPipeline.from_pretrained(base_model_id, torch_dtype=torch.float16).to("cuda")
print("✅ Base model loaded.")

# --- 1. Generate image with the BASE model ---
prompt_base = "a portrait of a young woman, rendered in Qajar style"
seed = 12345 # Use a fixed seed for reproducibility
generator = torch.Generator("cuda").manual_seed(seed)

print(f"\nGenerating image with BASE model...\nPrompt: {prompt_base}")
base_image = pipe(
    prompt_base,
    num_inference_steps=30,
    generator=generator,
    guidance_scale=7.5
).images[0]
print("✅ Base image generated.")


# --- 2. Load the LoRA and generate the STYLED image ---
print("\nLoading LoRA weights...")
try:
    pipe.load_lora_weights(lora_path)
    print("✅ LoRA weights loaded successfully.")
except Exception as e:
    print(f"❌ Error loading LoRA weights: {e}")
    print("Please ensure the lora_path is correct and the file exists.")

# The prompt for the LoRA must include the trigger word
generator = torch.Generator("cuda").manual_seed(seed) # Reset generator for a fair comparison

print(f"\nGenerating image with LoRA...\nPrompt: {prompt_base}")
lora_image = pipe(
    prompt_base,
    num_inference_steps=30,
    generator=generator,
    guidance_scale=7.5
).images[0]
print("✅ LoRA image generated.")

# --- 3. Compare the results ---
print("\n--- Comparison ---")

# Create a new image to display them side-by-side
width, height = base_image.size
comparison_image = Image.new("RGB", (width * 2, height))
comparison_image.paste(base_image, (0, 0))
comparison_image.paste(lora_image, (width, 0))

# Display the images
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.imshow(comparison_image)
plt.title("Left: Base Model Output | Right: LoRA Model Output")
plt.axis('off')
plt.show()

# Display individual images with their prompts for clarity
fig, axs = plt.subplots(1, 2, figsize=(12, 7))

axs[0].imshow(base_image)
axs[0].set_title("Base Model Result")
axs[0].axis('off')
axs[0].text(0, height + 30, f"Prompt: {prompt_base}", wrap=True, fontsize=9)


axs[1].imshow(lora_image)
axs[1].set_title("LoRA Model Result")
axs[1].axis('off')
axs[1].text(0, height + 30, f"Prompt: {prompt_base}", wrap=True, fontsize=9)

plt.tight_layout()
plt.show()
# Out:
# Loading base model pipeline...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# scheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# ✅ Base model loaded.
#
# Generating image with BASE model...
# Prompt: a portrait of a young woman, rendered in Qajar style
#   0%|          | 0/30 [00:00<?, ?it/s]
# ✅ Base image generated.
#
# Loading LoRA weights...
# No LoRA keys associated to CLIPTextModel found with the prefix='text_encoder'. This is safe to ignore if LoRA state dict didn't originally have any CLIPTextModel related params. You can also try specifying `prefix=None` to resolve the warning. Otherwise, open an issue if you think it's unexpected: https://github.com/huggingface/diffusers/issues/new
# ✅ LoRA weights loaded successfully.
#
# Generating image with LoRA...
# Prompt: a portrait of a young woman, rendered in Qajar style
#   0%|          | 0/30 [00:00<?, ?it/s]
# ✅ LoRA image generated.
#
# --- Comparison ---

# %% [markdown]
# ## code snippet 2

# %%
# Part 1: A more robust script to merge a Kohya LoRA and save the model.

import torch
from safetensors.torch import load_file
from diffusers import StableDiffusionPipeline
import os

# --- Configuration ---
base_model_id = "runwayml/stable-diffusion-v1-5"
lora_path = "/content/drive/MyDrive/Colab_Notebooks/Computer_Vision/Assignment08_SD_GEN/Qajar_LoRA_Model/last.safetensors"
merged_model_path = "/content/Qajar_Merged_Model_Final"
# Lora weight: 0.8 is a good starting point. Adjust if the style is too strong/weak.
LORA_WEIGHT = 0.8

# --- 1. Load the Base Stable Diffusion Model ---
print(f"Loading base model: {base_model_id}")
pipe = StableDiffusionPipeline.from_pretrained(
    base_model_id,
    torch_dtype=torch.float16
).to("cuda")


# --- 2. Load the LoRA weights from the safetensors file ---
print("Loading LoRA weights...")
lora_state_dict = load_file(lora_path)

# --- 3. Manually Merge the LoRA into the UNet ---
print("Merging LoRA into the UNet...")
unet = pipe.unet
unet_state_dict = unet.state_dict()

for key in unet_state_dict.keys():
    # Check if the key has a corresponding LoRA weight
    # LoRA keys are usually named like 'lora_unet_down_blocks_0_attentions_0_proj_in.lora_down.weight'
    # We need to transform this to the UNet key format.

    lora_key_name_down = key.replace(".", "_") + ".lora_down.weight"
    lora_key_name_up = key.replace(".", "_") + ".lora_up.weight"

    if lora_key_name_down in lora_state_dict:
        lora_down_weight = lora_state_dict[lora_key_name_down].to(torch.float16)
        lora_up_weight = lora_state_dict[lora_key_name_up].to(torch.float16)

        # W_merged = W_original + (alpha * W_lora_up @ W_lora_down)
        merged_weight = unet_state_dict[key] + (LORA_WEIGHT * (lora_up_weight @ lora_down_weight))
        unet_state_dict[key] = merged_weight

# Load the updated weights into the UNet
unet.load_state_dict(unet_state_dict)


# --- 4. (Optional but Recommended) Merge into Text Encoder for textual inversion concepts ---
# This part is for LoRAs that also trained concepts on the text encoder.
# If your LoRA is purely stylistic, this might not have a big effect, but it's good practice.
print("Merging LoRA into the Text Encoder (if applicable)...")
text_encoder = pipe.text_encoder
text_encoder_state_dict = text_encoder.state_dict()

# This part needs to be adapted based on how LoRA for text_encoder keys are named.
# A common pattern is 'lora_te_...'. We will skip this for now as most style LoRAs
# If you trained a specific token, this section would need to be expanded.


# --- 5. Save the final merged model ---
print(f"Saving fully merged model to: {merged_model_path}")
if not os.path.exists(merged_model_path):
    os.makedirs(merged_model_path)

pipe.save_pretrained(merged_model_path)
print("\nMerge complete! Your new model is saved and should be loadable.")
# Out:
# Loading base model: runwayml/stable-diffusion-v1-5
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading LoRA weights...
# Merging LoRA into the UNet...
# Merging LoRA into the Text Encoder (if applicable)...
# Saving fully merged model to: /content/Qajar_Merged_Model_Final
#
# Merge complete! Your new model is saved and should be loadable.

# %%
import torch
from diffusers import StableDiffusionPipeline, DPMSolverMultistepScheduler
from PIL import Image
from IPython.display import display
import os

# --- Configuration ---
merged_model_path = "/content/Qajar_Merged_Model_Final"
base_model_id = "runwayml/stable-diffusion-v1-5"
prompt = "a portrait of a young woman, rendered in Qajar style"
seed = 42 # Use a fixed seed for reproducibility

# --- 1. Generate Image with your MERGED Model ---
print(f"Loading your merged Qajar Style model from: {merged_model_path}")
pipe_qajar = StableDiffusionPipeline.from_pretrained(
    merged_model_path,
    torch_dtype=torch.float16
).to("cuda")
pipe_qajar.scheduler = DPMSolverMultistepScheduler.from_config(pipe_qajar.scheduler.config)

# Use a generator with a fixed seed
generator = torch.Generator("cuda").manual_seed(seed)
print("Generating image with the MERGED model...")
image_merged = pipe_qajar(prompt, generator=generator, num_inference_steps=25).images[0]
image_merged.save("qajar_style_from_merged_model.png")
print("Saved merged model output as 'qajar_style_from_merged_model.png'")


# --- 2. Generate Image with the BASE Model for Comparison ---
print(f"\nLoading original BASE model: {base_model_id}")
pipe_base = StableDiffusionPipeline.from_pretrained(
    base_model_id,
    torch_dtype=torch.float16
).to("cuda")
pipe_base.scheduler = DPMSolverMultistepScheduler.from_config(pipe_base.scheduler.config)

# IMPORTANT: Reset the generator with the same seed to ensure the initial noise is identical
# This is crucial for a fair A/B comparison.
generator = torch.Generator("cuda").manual_seed(seed)
print("Generating image with the BASE model...")
image_base = pipe_base(prompt, generator=generator, num_inference_steps=25).images[0]
image_base.save("qajar_style_from_base_model.png")
print("Saved base model output as 'qajar_style_from_base_model.png'")


# --- 3. Display Both Images for Individual Review ---
print("\n" + "="*50)
print("--- Image Comparison ---")
print("="*50)

# Display Merged Model Image
print("\nResult from your MERGED 'Qajar Style' Model:")
display(image_merged)

# Display Base Model Image
print("\nResult from the original 'stable-diffusion-v1-5' BASE Model:")
display(image_base)


# --- 4. (Bonus) Create and Display a Side-by-Side Comparison Image ---
def create_side_by_side_image(img1, img2, labels=["Merged Model", "Base Model"]):
    """Combines two PIL images horizontally with labels."""
    # To add text, we need to convert to RGBA and create a drawing context
    img1 = img1.convert("RGBA")
    img2 = img2.convert("RGBA")

    # Create a new image with space for labels
    dst = Image.new('RGB', (img1.width + img2.width, img1.height), color=(255, 255, 255))

    dst.paste(img1, (0, 0))
    dst.paste(img2, (img1.width, 0))
    return dst

print("\n" + "="*50)
print("--- Side-by-Side Comparison ---")
print("="*50)

comparison_image = create_side_by_side_image(image_merged, image_base)
comparison_image.save("comparison_merged_vs_base.png")
print("\nCreated a side-by-side comparison image: 'comparison_merged_vs_base.png'")
display(comparison_image)
# Out:
# Loading your merged Qajar Style model from: /content/Qajar_Merged_Model_Final
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Generating image with the MERGED model...
#   0%|          | 0/25 [00:00<?, ?it/s]
# Saved merged model output as 'qajar_style_from_merged_model.png'
#
# Loading original BASE model: runwayml/stable-diffusion-v1-5
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Generating image with the BASE model...
#   0%|          | 0/25 [00:00<?, ?it/s]
# Saved base model output as 'qajar_style_from_base_model.png'
#
# ==================================================
# --- Image Comparison ---
# ==================================================
#
# Result from your MERGED 'Qajar Style' Model:
# <PIL.Image.Image image mode=RGB size=512x512>
# Result from the original 'stable-diffusion-v1-5' BASE Model:
# <PIL.Image.Image image mode=RGB size=512x512>
# ==================================================
# --- Side-by-Side Comparison ---
# ==================================================
#
# Created a side-by-side comparison image: 'comparison_merged_vs_base.png'
# <PIL.Image.Image image mode=RGB size=1024x512>
